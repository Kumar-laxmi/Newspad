# %%
import requests
API_KEY = '95bcdd235c90417cb39f254809479546'

# %%
url = f'https://newsapi.org/v2/top-headlines?country=in&apiKey={API_KEY}'
response = requests.get(url)
data = response.json()
articles = data['articles']

# %%
articles
# Out:
# [{'source': {'id': None, 'name': 'The Indian Express'},
#   'author': 'Express Web Desk',
#   'title': 'Congress Protest Live Updates: Rahul, Priyanka Gandhi detained; Congress leaders protest across the country - The Indian Express',
#   'description': 'Congress Protest Live: In the capital cities across India, the state units would organise marches to Raj Bhavans in which MLAs, MLCs, former MPs and senior leaders will also take part.',
#   'url': 'https://indianexpress.com/article/india/congress-protest-live-updates-mps-march-rashtrapati-bhawan-price-rise-ed-action-8070800/',
#   'urlToImage': 'https://images.indianexpress.com/2022/08/Cong-leaders-detained.jpg',
#   'publishedAt': '2022-08-05T08:30:10Z',
#   'content': 'Piyush Goyal and Mallikarjun Kharge (Photo: Congress/File)\r\nMallikarjun Kharge, Piyush Goyal spar in Rajya Sabha over ED summons to Congress leaders\r\nLeader of Opposition in Rajya Sabha Mallikarjun K… [+942 chars]'},
#  {'source': {'id': None, 'name': 'YouTube'},
#   'author': None,
#   'title': "S.KOREA'S DANURI LAUNCHED INTO SPACE FOR LUNAR MISSION - Arirang News",
#   'description': "한국, 달 탐사 첫 발Up next... we turn to... a scholar... in the field... for her thoughts... on South Korea's first step... to its lunar expedition.I have Doctor Mi...",
#   'url': 'https://www.youtube.com/watch?v=Mpy8zw9LQU4',
#   'urlToImage': 'https://i.ytimg.com/vi/Mpy8zw9LQU4/maxresdefault.jpg',
#   'publishedAt': '2022-08-05T08:16:13Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'Zee Business'},
#   'author': 'ZeeBiz WebTeam',
#   'title': 'Nothing Phone 1 India price, sale on Flipkart, specifications and more - All you need to know - Zee Business',
#   'description': 'Nothing Phone 1 India price:\xa0The Nothing Phone (1) price in India is Rs 32,999 for the 8GB + 128GB configuration variant. The smartphone also retails in 8GB + 256GB and 12GB + 256GB configurations that are priced at Rs 35,999 and Rs 38,999 respectively.',
#   'url': 'https://www.zeebiz.com/technology/mobiles/news-nothing-phone-1-india-price-sale-on-flipkart-specifications-and-more-all-you-need-to-know-192932',
#   'urlToImage': 'https://cdn.zeebiz.com/sites/default/files/2022/08/05/193627-untitled-design-2022-08-05t123303527.jpg',
#   'publishedAt': '2022-08-05T07:05:00Z',
#   'content': 'Nothing Phone 1: After its launch last month in India and globally, the most-hyped smartphone Nothing Phone (1) will be going on the third sale today.\xa0 Nothing Phone (1)\xa0 went on sale on July 21 and … [+2283 chars]'},
#  {'source': {'id': None, 'name': 'Hindustan Times'},
#   'author': 'HT Tech',
#   'title': 'This asteroid got so close to the Sun, it turned blue; Check shocking impact - HT Tech',
#   'description': 'Among all the asteroids, Phaethon gets the closest to the Sun. Know how this shocking transformation into a blue asteroid happened.',
#   'url': 'https://tech.hindustantimes.com/tech/news/this-asteroid-got-so-close-to-the-sun-it-turned-blue-check-shocking-impact-71659682539912.html',
#   'urlToImage': 'https://images.hindustantimes.com/tech/img/2022/08/05/1600x900/SPACE-EXPLORATION-ASTEROID-0_1644738514217_1659682603447_1659682603447.JPG',
#   'publishedAt': '2022-08-05T06:59:33Z',
#   'content': 'Asteroids are the most mysterious objects in the sky. Take the example of asteroid 16 Psyche, where NASA plans to send a spacecraft in 2023, which is made up of various metals. Or the asteroid Bennu,… [+2148 chars]'},
#  {'source': {'id': None, 'name': 'Hindustan Times'},
#   'author': 'hindustantimes.com',
#   'title': 'Leucocyte Telomere Length linked to obesity in pre-diabetic and diabetic women - Hindustan Times',
#   'description': 'LTL is known to be linked with aging and associated diseases, such as obesity, type 2 diabetes, and cardiovascular disease. This study investigated the relationship of LTL in pre-diabetic women, and specifically, the relationship of LTL with obesity in women.…',
#   'url': 'https://www.hindustantimes.com/lifestyle/health/leucocyte-telomere-length-is-linked-to-obesity-in-pre-diabetic-and-type-2-diabetic-women-101659680515139.html',
#   'urlToImage': 'https://images.hindustantimes.com/img/2022/08/05/1600x900/diabetes_1652450112046_1659681068368_1659681068368.jpg',
#   'publishedAt': '2022-08-05T06:34:19Z',
#   'content': 'A recent study conducted jointly by Fortis C-DOC Hospital for Diabetes and Allied sciences and partners concluded that Leucocyte Telomere Length (LTL) is linked to obesity in pre-diabetic and type 2 … [+3668 chars]'},
#  {'source': {'id': None, 'name': 'Zee Business'},
#   'author': 'ZeeBiz WebTeam',
#   'title': 'LIVE: RBI Monetary Policy Review - MPC Meeting Outcome ANNOUNCED | 50 bps Repo Rate Hiked - TOP THIN - Zee Business',
#   'description': "The Reserve Bank of India's rate-setting panel on Wednesday began its three-day deliberations on t",
#   'url': 'https://www.zeebiz.com/india/live-updates-live-rbi-monetary-policy-august-2022-what-will-be-mpc-meeting-outcome-repo-rate-expectations-latest-news-192404',
#   'urlToImage': 'https://cdn.zeebiz.com/sites/default/files/2022/08/05/193591-rbi.jpg',
#   'publishedAt': '2022-08-05T06:27:25Z',
#   'content': 'LIVE:\xa0RBI MPC Meeting August 2022:\xa0Reserve Bank of India (RBI) Governor Shaktikanta Das on Friday announced the rise of policy rate by 50 basis points to 5.4 per cent. Announcing the decision of the … [+759 chars]'},
#  {'source': {'id': None, 'name': 'News18'},
#   'author': 'Srishti Choudhary',
#   'title': 'August 7, 9:18am: The Moment 750 Girls from Rural India Will Leave Their Mark in Space and Time With Azaadi - News18',
#   'description': 'On its maiden flight, ISRO’s smallest launch vehicle SSLV D-1 will carry AzaadiSAT, an 8-kg microsatellite carrying 75 small payloads developed by an all-girls team from 75 rural schools across India',
#   'url': 'https://www.news18.com/news/india/august-7-918am-the-moment-750-girls-from-rural-india-will-leave-their-mark-in-space-and-time-with-azaadisat-5691553.html',
#   'urlToImage': 'https://images.news18.com/ibnlive/uploads/2022/08/sslv-165967229616x9.png',
#   'publishedAt': '2022-08-05T05:33:00Z',
#   'content': 'On the morning of August 7, as ISROs Small Satellite Launch Vehicle (SSLV) leaves for its maiden spaceflight from Sriharikota, hundreds of girls who travelled from villages across states will be watc… [+4660 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'TIMESOFINDIA.COM',
#   'title': 'Shift the focus! Prostate cancer may NOT always show urinary symptoms, finds study - Times of India',
#   'description': 'Cancer in all its forms is dangerous, especially if it gets diagnosed at a later stage, where it becomes incurable. As far as prostate cancer is concerned, it is one of the most common and concerning cancers in men. Reportedly, it is the second most frequent …',
#   'url': 'https://timesofindia.indiatimes.com/life-style/health-fitness/health-news/shift-the-focus-prostate-cancer-may-not-always-show-urinary-symptoms-finds-study/photostory/93348853.cms',
#   'urlToImage': 'https://static.toiimg.com/photo/93348872.cms',
#   'publishedAt': '2022-08-05T05:30:00Z',
#   'content': 'A study published by a team at the University of Cambridge shares that focusing on urinary symptoms can be misleading when it comes to diagnosing prostate cancer.\r\n“When most people think of the symp… [+497 chars]'},
#  {'source': {'id': None, 'name': 'Hindustan Times'},
#   'author': 'Shishir Gupta',
#   'title': 'India miffed at Colombo for allowing PLA satellite tracker ship in Hambantota - Hindustan Times',
#   'description': 'A Luyang class guided missile destroyer with Type 071 Landing Platform Dock (LPD) is also transiting the Indian Ocean and headed towards the Chinese base in Djibouti on the eastern seaboard of Africa. | World News',
#   'url': 'https://www.hindustantimes.com/world-news/india-miffed-at-colombo-for-allowing-pla-satellite-tracker-ship-in-hambantota-101659675982026.html',
#   'urlToImage': 'https://images.hindustantimes.com/img/2022/08/05/1600x900/china_tracking_ship_at_hambantota_1659676165527_1659676165707_1659676165707.png',
#   'publishedAt': '2022-08-05T05:13:02Z',
#   'content': 'Under the cloak of a research and survey vessel, a Chinese Space and Satellite Tracking ship Yuan Wang 5 is headed towards China leased port of Hambantota in Sri Lanka on August 11 despite serious ob… [+2117 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'TIMESOFINDIA.COM',
#   'title': 'Garena Free Fire Max Redeem Codes for August 5, 2022: Win free diamonds, emote crates and more - Times of India',
#   'description': "The game's creators are constantly adding alphanumeric codes to the game. These codes provide players the opportunity to win free prizes. The codes ca",
#   'url': 'https://timesofindia.indiatimes.com/gadgets-news/garena-free-fire-max-redeem-codes-for-august-5-2022-win-free-diamonds-emote-crates-and-more/articleshow/93362388.cms',
#   'urlToImage': 'https://static.toiimg.com/thumb/msid-93362403,width-1070,height-580,imgsize-83248,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg',
#   'publishedAt': '2022-08-05T05:04:00Z',
#   'content': ''},
#  {'source': {'id': None, 'name': 'YouTube'},
#   'author': None,
#   'title': 'Royal Enfield Hunter 350: walk-around, exhaust note and design details | OVERDRIVE - OVERDRIVE',
#   'description': 'The #Hunter350 is the third J-series product from #RoyalEnfield after the Meteor and Classic 350. It uses similar underpinnings as the two motorcycles but is...',
#   'url': 'https://www.youtube.com/watch?v=qUai-RiwH3s',
#   'urlToImage': 'https://i.ytimg.com/vi/qUai-RiwH3s/maxresdefault.jpg',
#   'publishedAt': '2022-08-05T04:53:41Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'Republic World'},
#   'author': 'Shikhar Mehrotra',
#   'title': 'OnePlus 10T with Snapdragon 8+ Gen 1 and 150W fast charging launched globally - Republic World',
#   'description': 'The OnePlus 10T comes with a 6.7-inch 120Hz Fluid AMOLED display that has a touch response rate of 360Hz. Read more details about the smartphone here.',
#   'url': 'https://www.republicworld.com/technology-news/mobile/oneplus-10t-with-snapdragon-8-gen-1-and-150w-fast-charging-launched-globally-articleshow.html',
#   'urlToImage': 'https://img.republicworld.com/republic-prod/stories/promolarge/xhdpi/2ayfjgn4nimfwahe_1659673970.jpeg',
#   'publishedAt': '2022-08-05T04:39:00Z',
#   'content': "After launching a flagship smartphone earlier this year, OnePlus has launched yet another device called OnePlus 10T. It belongs to the 'T' series of smartphones by the company and takes after the One… [+2060 chars]"},
#  {'source': {'id': None, 'name': 'News18'},
#   'author': 'Sports Desk',
#   'title': 'CWG 2022, India Day 8 Full Schedule: Complete List of Events And Updated Timings For August 5 - News18',
#   'description': 'CWG 2022 India Day 8 Full Schedule August 5: Check here the complete list of events Indian contingent will take part on the eighth day of the ongoing Commonwealth Games 2022 in Birmingham.',
#   'url': 'https://www.news18.com/news/sports/cwg-2022-india-full-schedule-day-8-august-5-commonwealth-games-results-medal-tally-wrestling-badminton-squash-hockey-athletics-birmingham-5691409.html',
#   'urlToImage': 'https://images.news18.com/ibnlive/uploads/2022/08/pv-sindhu-ap-165966515916x9.jpg',
#   'publishedAt': '2022-08-05T04:33:00Z',
#   'content': 'Commonwealth Games 2022 Full List of India Schedule And Timings: Indias medal tally continues to grow after a superb seventh day of CWG 2022 in Birmingham. With six gold, seven silver and seven bronz… [+4041 chars]'},
#  {'source': {'id': None,
#    'name': 'International Business Times, India Edition'},
#   'author': 'Sami Khan',
#   'title': 'OnePlus Nord Buds CE first impressions - IBTimes India',
#   'description': "OnePlus Nord Buds may be a new product series in the company's extensive product lineup, it's got the expertise of OnePlus.",
#   'url': 'https://www.ibtimes.co.in/oneplus-nord-buds-ce-first-impressions-851075',
#   'urlToImage': 'https://data1.ibtimes.co.in/en/full/774480/oneplus-nord-buds-ce-review.jpg',
#   'publishedAt': '2022-08-05T04:32:00Z',
#   'content': "OnePlus Nord Buds CE is the latest addition to the company's audio lineup, targeted toward the masses. It is, after all, OnePlus' cheapest TWS earbuds, which automatically grabs some eyeballs. Natura… [+3788 chars]"},
#  {'source': {'id': None, 'name': 'Bollywood Life'},
#   'author': 'Nikita Thakkar',
#   'title': 'Karan Mehra vs Nisha Rawal: Yeh Rishta Kya Kehlata Hai star makes SHOCKING revelations about death threats; a - Bollywood Life',
#   'description': 'It was in May last year that Nisha Rawal had accused Karan Mehra of domestic violence. Now, the Yeh Rishta Kya Kehlata Hai star has shared his side of the story.',
#   'url': 'https://www.bollywoodlife.com/photos/karan-mehra-vs-nisha-rawal-yeh-rishta-kya-kehlata-hai-star-makes-shocking-revelations-about-death-threats-accuses-ex-wife-of-physically-assaulting-him-tv-galleries-entertainment-news-2148053/',
#   'urlToImage': 'https://st1.bollywoodlife.com/wp-content/uploads/2022/08/nisha-2-600x315.png',
#   'publishedAt': '2022-08-05T04:02:32Z',
#   'content': 'The actor also mentioned that Nisha Rawal, Rohit Sethia and Laxmi Rawal conspired against him. He claimed that they assaulted him while he was recuperating from COVID-19 and charged false allegations… [+513 chars]'},
#  {'source': {'id': None, 'name': 'NDTV News'},
#   'author': None,
#   'title': 'Japan Calls For "Immediate Cancellation" Of China Military Drills - NDTV',
#   'description': 'Japan\'s prime minister on Friday condemned China\'s firing of ballistic missiles during military drills around Taiwan, calling them a "serious problem that impacts our national security and the safety of our citizens".',
#   'url': 'https://www.ndtv.com/world-news/japan-tells-china-to-immediately-cancel-military-drills-around-taiwan-3226482',
#   'urlToImage': 'https://c.ndtvimg.com/2022-08/a4atrdi_fumio-kishida-and-nancy-pelosi-afp_625x300_05_August_22.jpg',
#   'publishedAt': '2022-08-05T03:38:58Z',
#   'content': "Nancy Pelosi is in Tokyo for the final leg of an Asian tour.\r\nTokyo: Japan's prime minister on Friday condemned China's firing of ballistic missiles during military drills around Taiwan, calling them… [+1968 chars]"},
#  {'source': {'id': None, 'name': 'Hindustan Times'},
#   'author': 'HT Education Desk',
#   'title': 'CBSE Compartment Exam 2022: Class 10, 12 timetable released, check schedule here - Hindustan Times',
#   'description': 'CBSE Compartment Exam 2022 time table released. Candidates can check the Class 10, 12 schedule below.',
#   'url': 'https://www.hindustantimes.com/education/board-exams/cbse-compartment-exam-2022-class-10-12-timetable-released-check-schedule-here-101659669045030.html',
#   'urlToImage': 'https://images.hindustantimes.com/img/2022/08/05/1600x900/cbse-class-10-12-exams-begin_9806f424-62e7-11e8-a998-12ee0acfa260_1659669334209_1659669334209.jpg',
#   'publishedAt': '2022-08-05T03:18:01Z',
#   'content': 'Central Board of Secondary Education has released CBSE Compartment Exam 2022 timetable. The Class 10, 12 schedule is available to all appearing candidates on the official site of CBSE on cbse.gov.in.… [+895 chars]'},
#  {'source': {'id': None, 'name': 'India Today'},
#   'author': None,
#   'title': 'Red alert issued in 8 districts in Kerala as heavy rainfall lashes state - India Today',
#   'description': 'The Kerala government is conducting round the clock rescue and relief operations to evacuate people as a red alert was issued in eight districts of the state.',
#   'url': 'https://www.indiatoday.in/india/story/kerala-flood-heavy-rainfall-red-alert-river-overflowing-1984006-2022-08-05',
#   'urlToImage': 'https://akm-img-a-in.tosshub.com/indiatoday/images/story/202208/Kerala-rains-5-647x363.jpeg?2NVvjoFHW6SKbw88kBBjCX631cTAUSKl',
#   'publishedAt': '2022-08-05T03:11:20Z',
#   'content': 'The India Meteorological Department (IMD) on Thursday issued a red alert in eight districts of Kerala as heavy rainfall continued to lash various parts of the state. Many people have been displaced f… [+1472 chars]'},
#  {'source': {'id': None, 'name': 'Thetelugufilmnagar.com'},
#   'author': None,
#   'title': 'Sita Ramam Telugu Movie Review | Dulquer Salmaan | Mrunal Thakur | Rashmika | Sita Ramam Movie Review | Sita Ramam Review | Sita Ramam Movie Review And Rating | Sita Ramam Movie Highlights | Sita Ramam Movie Plus Points | Sita Ramam Movie - Telugu Filmnagar',
#   'description': 'Sita Ramam Telugu Movie Review - Sita Ramam, the periodic romantic drama from Hanu Raghavapudi, has positive buzz and talk around it, promising a feel-good cinematic experience with the trailer and the other promos that have been released so far. Sita Ramam M…',
#   'url': 'https://www.thetelugufilmnagar.com/2022/08/05/sita-ramam-telugu-movie-review/',
#   'urlToImage': 'https://www.thetelugufilmnagar.com/wp-content/uploads/2022/08/Sita-Ramam-Telugu-Movie-review.webp',
#   'publishedAt': '2022-08-05T02:45:44Z',
#   'content': 'Sita Ramam Movie Synopsis:\r\nSita Ramam, the periodic romantic drama from Hanu Raghavapudi, has positive buzz and talk around it, promising a feel-good cinematic experience with the trailer and the ot… [+3783 chars]'},
#  {'source': {'id': 'espn-cric-info', 'name': 'ESPN Cric Info'},
#   'author': 'Valkerie Baynes',
#   'title': "Australia's team of matchwinners will take some stopping - ESPNcricinfo",
#   'description': 'Whenever there is a hint of the team being in trouble someone is there to turn things around',
#   'url': 'https://www.espncricinfo.com/story/commonwealth-games-2022-australias-team-of-matchwinners-will-take-some-stopping-1327658',
#   'urlToImage': 'https://img1.hscicdn.com/image/upload/f_auto/lsci/db/PICTURES/CMS/343500/343593.6.jpg',
#   'publishedAt': '2022-08-05T02:43:22Z',
#   'content': 'Not for the first time, Beth Mooney and Tahlia McGrath combined in a match-winning stand\xa0\xa0•\xa0\xa0Getty Images'}]
