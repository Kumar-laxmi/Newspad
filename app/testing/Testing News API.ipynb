# %%
import requests
from bs4 import BeautifulSoup

API_KEY = '95bcdd235c90417cb39f254809479546'

# %%
url = f'https://newsapi.org/v2/top-headlines?country=in&apiKey={API_KEY}'
response = requests.get(url)
data = response.json()
articles1 = data['articles']

articles1
# Out:
# [{'source': {'id': None, 'name': 'Dailyexcelsior.com'},
#   'author': 'https://www.facebook.com/dailyexcelsior',
#   'title': '1 in 8 COVID-19 patients develop long-term symptoms: Lancet study - Jammu Kashmir Latest News | Tourism | Breaking News J&K - Top Stories',
#   'description': 'LONDON, Aug 5: One in eight adults who are infected with SARS-CoV-2 experience long term symptoms due to COVID-19, according to one of the most comprehensive studies on the viral disease to date published in The Lancet journal on Friday. The study provides on…',
#   'url': 'https://www.dailyexcelsior.com/1-in-8-covid-19-patients-develop-long-term-symptoms-lancet-study-2/',
#   'urlToImage': 'https://www.dailyexcelsior.com/wp-content/uploads/2022/08/1-in-8-COVID-19-patients-develop-long-term.jpg',
#   'publishedAt': '2022-08-05T21:30:57Z',
# ...

# %%
 url = f'https://newsapi.org/v2/top-headlines?category=sport&apiKey={API_KEY}'
response = requests.get(url)
data = response.json()
articles = data['articles']

articles
# Out:
# [{'source': {'id': 'news-com-au', 'name': 'News.com.au'},
#   'author': 'Steve Zemek',
#   'title': 'Moment star flew into rage after ‘sex act’ - news.com.au',
#   'description': '<p><b></b>An NRL star nearly died after losing 2.5 litres of blood when he slashed himself while punching a window after catching his fiancee performing a sex act on his team mate, a court has heard.</p>',
#   'url': 'https://www.news.com.au/sport/nrl/huge-court-decision-for-exnrl-star-michael-lichaa/news-story/06d6abf98bd37f695a01e4d33f687779',
#   'urlToImage': 'https://content.api.news/v3/images/bin/e422b9583cd30f1055a893d41c68ba4a',
#   'publishedAt': '2022-08-06T00:37:12Z',
#   'content': 'An NRL star nearly died after losing 2.5 litres of blood when he slashed himself while punching a window after catching his fiancee performing a sex act on his team mate, a court has heard.\r\nEx-Shark… [+4953 chars]'},
#  {'source': {'id': None, 'name': 'Sina.com.cn'},
#   'author': '小风',
# ...

# %% [markdown]
# # Testing Live cricket scores

# %%
html_text = requests.get('https://sports.ndtv.com/cricket/live-scores').text
soup = BeautifulSoup(html_text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
sect = soup.find_all('div', class_='sp-scr_wrp')
section = sect[0]
description = section.find('span', class_='description').text
location = section.find('span', class_='location').text
current = section.find('div', class_='scr_dt-red').text
link = "https://sports.ndtv.com/" + \
    section.find('a', class_='scr_ful-sbr-txt').get('href')

# %%
try:
    status = section.find_all('div', class_="scr_dt-red")[1].text
    block = section.find_all('div', class_='scr_tm-wrp')
    team1_block = block[0]
    team1_name = team1_block.find('div', class_='scr_tm-nm').text
    team1_score = team1_block.find('span', class_='scr_tm-run').text
    team2_block = block[1]
    team2_name = team2_block.find('div', class_='scr_tm-nm').text
    team2_score = team2_block.find('span', class_='scr_tm-run').text
    print(description)
    print(location)
    print(status)
    print(current)
    print(team1_name.strip() + ":" + team1_score.strip())
    print(team2_name.strip() + ":" + team2_score.strip())
    print(link)
except:
    print("Data not available")
# Out:
# Data not available
